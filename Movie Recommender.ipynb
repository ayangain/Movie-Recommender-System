# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movie=pd.read_csv('movie.csv')
rating=pd.read_csv('rating.csv')
tag=pd.read_csv('tag.csv')
link=pd.read_csv('link.csv')
gtag=pd.read_csv('genome_tags.csv')
gscore=pd.read_csv('genome_scores.csv')

# %%
movie.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
rating.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
tag.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
link.isnull().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     252
# dtype: int64

# %%
gtag.isnull().sum()
# Out:
# tagId    0
# tag      0
# dtype: int64

# %%
gscore.isnull().sum()
# Out:
# movieId      0
# tagId        0
# relevance    0
# dtype: int64

# %%
movie.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
rating.head(2)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16

# %%
tag.head(2)
# Out:
#    userId  movieId          tag            timestamp
# 0      18     4141  Mark Waters  2009-04-24 18:19:40
# 1      65      208    dark hero  2013-05-10 01:41:18

# %%
link.head(2)
# Out:
#    movieId  imdbId  tmdbId
# 0        1  114709   862.0
# 1        2  113497  8844.0

# %%
gtag.head(2)
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)

# %%
gscore.head(10)
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675
# 5        1      6    0.21700
# 6        1      7    0.06700
# 7        1      8    0.26275
# 8        1      9    0.26200
# 9        1     10    0.03200

# %%
gscore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11709768 entries, 0 to 11709767
# Data columns (total 3 columns):
# movieId      int64
# tagId        int64
# relevance    float64
# dtypes: float64(1), int64(2)
# memory usage: 268.0 MB

# %%
x=rating['userId'].value_counts()>200
filter_user=x[x].index.tolist()
filter_user
# Out:
# [118205,
#  8405,
#  82418,
#  121535,
#  125794,
#  74142,
#  34576,
#  131904,
#  83090,
#  59477,
#  130767,
#  79159,
#  8963,
#  15617,
#  92011,
#  71975,
#  20132,
#  46470,
#  88820,
#  63147,
#  130459,
#  120575,
#  9544,
#  31122,
#  18611,
#  125978,
#  18138,
#  91193,
#  111549,
#  68026,
#  41267,
#  51703,
#  92269,
#  70201,
#  35128,
#  105580,
#  14705,
#  54465,
#  114406,
#  136268,
#  12131,
#  53346,
#  24688,
#  107326,
#  131347,
#  26867,
#  27469,
#  119048,
#  123606,
#  67346,
#  86529,
#  22901,
#  129583,
#  131894,
#  91867,
#  7201,
#  24219,
#  62812,
#  61168,
#  68063,
#  51558,
#  97853,
#  32344,
#  80092,
#  103223,
#  107640,
#  128258,
#  79531,
#  128309,
#  92956,
#  118754,
#  76630,
#  106441,
#  59414,
#  113668,
#  122995,
#  116189,
#  50297,
#  52260,
#  72008,
#  33736,
#  52009,
#  43194,
#  117144,
#  3907,
#  137202,
#  27053,
#  31404,
#  42929,
#  119531,
#  135425,
#  66763,
#  116317,
#  64843,
#  131961,
#  2261,
#  42204,
# ...

# %%
rating.shape
# Out:
# (20000263, 4)

# %%
rating['movieId'].nunique()
# Out:
# 26744

# %%
ratings=rating[rating['userId'].isin(filter_user)]
ratings.shape
# Out:
# (12426476, 4)

# %%
x=ratings['movieId'].value_counts()>200
filter_mov=x[x].index.tolist()
filter_mov
# Out:
# [356,
#  296,
#  2571,
#  480,
#  593,
#  260,
#  1270,
#  1196,
#  1198,
#  1210,
#  318,
#  1580,
#  589,
#  1,
#  2858,
#  110,
#  2762,
#  780,
#  1240,
#  1265,
#  1097,
#  608,
#  50,
#  2028,
#  1291,
#  47,
#  377,
#  527,
#  2959,
#  1136,
#  2716,
#  32,
#  457,
#  1036,
#  858,
#  4993,
#  1214,
#  3578,
#  1721,
#  2628,
#  592,
#  4306,
#  1527,
#  541,
#  648,
#  150,
#  1197,
#  364,
#  1704,
#  1682,
#  5952,
#  1200,
#  380,
#  1089,
#  367,
#  3793,
#  1923,
#  588,
#  4226,
#  2997,
#  590,
#  500,
#  1193,
#  2115,
#  1206,
#  924,
#  1387,
#  597,
#  1961,
#  1258,
#  2918,
#  733,
#  1617,
#  7153,
#  5349,
#  3996,
#  1213,
#  919,
#  2683,
#  2291,
#  344,
#  4963,
#  586,
#  1517,
#  2987,
#  1073,
#  6539,
#  5445,
#  2916,
#  1222,
#  736,
#  1208,
#  1221,
#  2174,
#  2706,
#  1101,
#  2011,
#  34,
#  1732,
#  1784,
#  1246,
#  1393,
#  1917,
#  1968,
#  231,
#  2396,
#  2797,
#  1307,
#  4886,
#  293,
#  1259,
#  1610,
#  595,
#  6377,
#  587,
#  1573,
# ...

# %%
ratings=ratings[ratings['movieId'].isin(filter_mov)]

# %%
ratings.shape
# Out:
# (11856420, 4)

# %%
ratings
# Out:
#           userId  movieId  rating            timestamp
# 541            7        3     3.0  2002-01-16 19:14:23
# 542            7        7     3.0  2002-01-16 19:10:20
# 543            7       11     4.0  2002-01-16 19:04:49
# 544            7       15     2.0  2002-01-16 19:18:52
# 545            7       16     3.0  2002-01-16 18:22:58
# ...          ...      ...     ...                  ...
# 20000257  138493    68319     4.5  2009-12-07 18:15:20
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
#
# [11856420 rows x 4 columns]

# %%
link['movieId'].nunique()
# Out:
# 27278

# %%
ratings['movieId'].nunique()
# Out:
# 6215

# %%
tag['movieId'].nunique()
# Out:
# 19545

# %%
movie['movieId'].nunique()
# Out:
# 27278

# %%
gscore['movieId'].nunique()
# Out:
# 10381

# %%
movie['title'].nunique()
# Out:
# 27262

# %%
tag.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
g=tag[tag['tag'].isnull()]['movieId'].values.tolist()

# %%
tagfilter=tag[tag['tag'].isnull()].index
ratfiler=ratings[ratings['movieId'].isin(g)].index
linkfilter=link[link['movieId'].isin(g)].index
moviefilter=movie[movie['movieId'].isin(g)].index
gscorefilter=gscore[gscore['movieId'].isin(g)].index

# %%
tag.drop(columns='timestamp',inplace=True)

# %%
tag
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
tag.drop(tagfilter,inplace=True)
ratings.drop(ratfiler,inplace=True)
link.drop(linkfilter,inplace=True)
movie.drop(moviefilter,inplace=True)
gscore.drop(gscorefilter,inplace=True)

# %%
rating['movieId'].nunique()
# Out:
# 26744

# %%
rating
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
movie.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
tag.isnull().sum()
# Out:
# userId     0
# movieId    0
# tag        0
# dtype: int64

# %%
link.isnull().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     252
# dtype: int64

# %%
gscore.isnull().sum()
# Out:
# movieId      0
# tagId        0
# relevance    0
# dtype: int64

# %%
gtag.isnull().sum()
# Out:
# tagId    0
# tag      0
# dtype: int64

# %%
rating['userId'].value_counts()
# Out:
# 118205    9254
# 8405      7515
# 82418     5646
# 121535    5520
# 125794    5491
#           ...
# 59390       20
# 23558       20
# 34668       20
# 80291       20
# 58028       20
# Name: userId, Length: 138493, dtype: int64

# %%
movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
splitDataFrameList(movie,"title","(")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-e236732e6f75> in <module>
# ----> 1 splitDataFrameList(movie,"title","(")
#
# NameError: name 'splitDataFrameList' is not defined

# %%
sep = movie['title'].str.extract('(.*)\((\d{4})\)', expand=False)

# %%
sep.reset_index()
# Out:
#        index                             0     1
# 0          0                    Toy Story   1995
# 1          1                      Jumanji   1995
# 2          2             Grumpier Old Men   1995
# 3          3            Waiting to Exhale   1995
# 4          4  Father of the Bride Part II   1995
# ...      ...                           ...   ...
# 27258  27273        Kein Bund für's Leben   2007
# 27259  27274       Feuer, Eis & Dosenbier   2002
# 27260  27275                  The Pirates   2014
# 27261  27276                 Rentun Ruusu   2001
# 27262  27277                    Innocence   2014
#
# [27263 rows x 3 columns]

# %%
movie['u']=sep[1]

# %%
movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres     u
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                       Adventure|Children|Fantasy  1995
# 2                                   Comedy|Romance  1995
# 3                             Comedy|Drama|Romance  1995
# 4                                           Comedy  1995
# ...

# %%
movie['title'].nunique()
# Out:
# 27247

# %%
movie['u'].isnull().sum()
# Out:
# 22

# %%
movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres     u
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                       Adventure|Children|Fantasy  1995
# 2                                   Comedy|Romance  1995
# 3                             Comedy|Drama|Romance  1995
# 4                                           Comedy  1995
# ...

# %%
movie['title'].str.extract('(\d+)').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-270bbcbe6b9c> in <module>
# ----> 1 movie['title'].str.extract('(\d+)').astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
import re
movie['title'].apply(lambda x: re.search(r'\d+', x).group())
# Out:
#   File "<ipython-input-152-78058add1083>", line 2
#     movie['title'].apply(lambda x: re.search(r'\d+', x)movie.group())
#                                                            ^
# SyntaxError: invalid syntax

# %%
re.search('\s\d\d\d\d',movie['title'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-453810dc505d> in <module>
# ----> 1 re.search('\s\d\d\d\d',movie['title'])
#
# ~\Anaconda3\lib\re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
#Using regular expressions to find a year stored between parentheses
#We specify the parentheses so we don't conflict with movies that have years in their titles.
movie['year'] = movie.title.str.extract('(\(\d\d\d\d\))',expand=False)
#Removing the parentheses.
movie['year'] = movie.year.str.extract('(\d\d\d\d)',expand=False)
# Note that expand=False simply means do not add this adjustment as an additional column to the data frame.
#Removing the years from the 'title' column.
movie['title'] = movie.title.str.replace('(\(\d\d\d\d\))', '')
#Applying the strip function to get rid of any ending white space characters that may have appeared, using lambda function.
movie['title'] = movie['title'].apply(lambda x: x.strip())

# %%
movie.isnull().sum()
# Out:
# movieId     0
# title       0
# genres      0
# u          22
# year       22
# dtype: int64
